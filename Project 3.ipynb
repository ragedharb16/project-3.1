# %% [markdown]
# Project 3 Part 1 (Core)
#
# Business Problem For this project, you have been hired to produce a MySQL database on Movies from a subset of IMDB's publicly available dataset. Ultimately, you will use this database to analyze what makes a movie successful and will provide recommendations to the stakeholder on how to make a successful movie.

# %%
#import the package
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# !pip install tmdbsimple
import os, json, math, time
from tqdm.notebook import tqdm_notebook
# Out:
# Requirement already satisfied: tmdbsimple in c:\users\raged\anaconda3\envs\dojo-env\lib\site-packages (2.9.1)
# Requirement already satisfied: requests in c:\users\raged\anaconda3\envs\dojo-env\lib\site-packages (from tmdbsimple) (2.27.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\raged\anaconda3\envs\dojo-env\lib\site-packages (from requests->tmdbsimple) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\raged\anaconda3\envs\dojo-env\lib\site-packages (from requests->tmdbsimple) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\raged\anaconda3\envs\dojo-env\lib\site-packages (from requests->tmdbsimple) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\raged\anaconda3\envs\dojo-env\lib\site-packages (from requests->tmdbsimple) (1.26.8)

# %%
# upload the files
basics = pd.read_csv('https://datasets.imdbws.com/title.basics.tsv.gz', 
                     sep='\t', low_memory=False)

# %%
ratings = pd.read_csv('https://datasets.imdbws.com/title.ratings.tsv.gz', 
                      sep='\t', low_memory=False)

# %%
akas = pd.read_csv('https://datasets.imdbws.com/title.akas.tsv.gz', 
                   sep='\t', low_memory=False)

# %%
# replace the bad spelling missing values with Nan
basics = basics.replace({'\\N':np.nan}) 
ratings = ratings.replace({'\\N':np.nan}) 
akas = akas.replace({'\\N':np.nan})

# %%
# getting just the movies
basics = basics.loc[basics['titleType'] == 'movie']

# %%
# deliting the missing values
basics = basics.dropna(subset = ['runtimeMinutes', 'genres','startYear'])

# %%
# loc the dates the request from us 
basics['startYear'] = basics['startYear'].astype(int)
basics = basics.loc[(basics['startYear'] >= 2000) 
                    & (basics['startYear'] <= 2022)]
# Out:
# C:\Users\raged\anaconda3\envs\dojo-env\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# taking out the documentary from our data
is_documentary = basics['genres'].str.contains('documentary',case=False)
basics = basics[~is_documentary]

# %%
basics['genres'].unique()
# Out:
# array(['Comedy,Fantasy,Romance', 'Drama', 'Drama,War',
#        'Comedy,Horror,Sci-Fi', 'Comedy', 'Comedy,Drama,Fantasy',
#        'Drama,Romance', 'Comedy,Mystery', 'Drama,Fantasy', 'Adventure',
#        'Musical,Romance', 'Action,Adventure,Drama', 'Action',
#        'Crime,Thriller', 'Comedy,Fantasy', 'Action,Crime,Drama',
#        'Action,Thriller', 'Comedy,Drama,Romance', 'Drama,Music,Romance',
#        'Comedy,Horror,Mystery', 'Crime,Drama,Thriller', 'Comedy,Drama',
#        'Action,Adventure,Animation', 'Comedy,Romance', 'Drama,Thriller',
#        'Comedy,Drama,Sci-Fi', 'Adventure,Family,Fantasy', 'Drama,History',
#        'Drama,History,War', 'Adventure,Animation,Comedy',
#        'Action,Adventure,Fantasy', 'Action,Drama,Sci-Fi',
#        'Biography,Drama,Romance', 'Horror,Mystery,Thriller',
#        'Comedy,Drama,Thriller', 'Animation,Family,Musical',
#        'Drama,Mystery,Thriller', 'Action,Adventure,Thriller',
#        'Action,Horror,Sci-Fi', 'Action,Adventure,Sci-Fi',
#        'Action,Adventure,Comedy', 'Animation,Drama,Family',
#        'Comedy,Family', 'Comedy,Crime', 'Comedy,Crime,Romance',
#        'Drama,Mystery,Romance', 'Crime,Mystery,Thriller', 'Horror',
#        'Action,Crime', 'Adventure,Animation,Drama', 'Action,Crime,Sci-Fi',
#        'Action,Drama,Sport', 'Thriller', 'Action,Crime,Fantasy',
#        'Fantasy', 'Adventure,Animation,Family', 'Horror,Mystery',
#        'Comedy,Drama,Music', 'Horror,Sci-Fi,Thriller',
#        'Drama,Family,Western', 'Animation,Comedy,Sci-Fi', 'Adult',
#        'Crime,Drama', 'Crime,Drama,Romance', 'Drama,Music',
#        'Biography,Comedy,Drama', 'Action,War', 'Action,Drama',
#        'Crime,Drama,Horror', 'Crime,Fantasy,Mystery', 'Biography',
#        'Comedy,Romance,Sci-Fi', 'Adventure,Comedy,Crime',
#        'Drama,History,Thriller', 'Drama,Fantasy,Sport', 'Action,Comedy',
#        'Comedy,Crime,Drama', 'Drama,Romance,Western',
#        'Action,Drama,Musical', 'Adult,Crime,Mystery', 'Drama,Family,War',
#        'Biography,Crime,Drama', 'Comedy,Horror', 'Comedy,Drama,Family',
#        'Comedy,Sci-Fi', 'Horror,Thriller', 'Biography,Drama',
#        'Comedy,Family,Romance', 'Action,Drama,Thriller',
#        'Adventure,Drama,History', 'Action,Adventure,Crime',
#        'Crime,Drama,Mystery', 'Drama,Mystery,Sci-Fi',
#        'Drama,Horror,Thriller', 'Drama,Romance,Thriller',
#        'Comedy,Music,Romance', 'Drama,Family', 'Drama,Thriller,War',
#        'Drama,Horror,Mystery', 'Crime', 'Biography,Drama,History',
#        'Adventure,Drama,Romance', 'Action,Crime,Thriller',
#        'Comedy,Crime,Mystery', 'Comedy,Thriller', 'Action,Sci-Fi',
#        'Adventure,Comedy,Drama', 'Crime,Horror', 'Comedy,Family,Mystery',
#        'Animation,Comedy,Fantasy', 'Fantasy,Horror',
#        'Comedy,Horror,Thriller', 'Action,Romance,Thriller',
#        'Adventure,Biography,Drama', 'Action,Comedy,Crime',
#        'Comedy,Drama,Mystery', 'Crime,Drama,Musical',
#        'Drama,Musical,Sport', 'Comedy,Family,Fantasy',
#        'Action,Drama,Romance', 'Crime,Horror,Mystery',
#        'Comedy,Crime,Thriller', 'Animation,Drama,History',
#        'Adventure,Comedy,Family', 'Comedy,Romance,Western',
#        'Biography,Drama,Music', 'Adventure,Comedy,Romance',
#        'Action,Comedy,Romance', 'Crime,Sci-Fi,Thriller', 'Drama,Western',
#        'Crime,Mystery', 'Action,Comedy,Sci-Fi', 'Comedy,Drama,Sport',
#        'Romance,Sci-Fi', 'Action,Crime,Mystery', 'Action,Comedy,Fantasy',
#        'Crime,Drama,Music', 'Comedy,Musical,Romance', 'Comedy,Music',
#        'Adventure,Sci-Fi,Thriller', 'Action,Adventure,Romance',
#        'Drama,Mystery', 'Animation,Comedy,Crime', 'Adventure,Family',
#        'Action,Drama,History', 'Drama,History,Romance',
#        'Action,Mystery,Thriller', 'Mystery,Thriller', 'Comedy,Musical',
#        'Drama,Sport', 'Drama,Fantasy,Romance', 'Adventure,Comedy,Fantasy',
#        'Drama,Horror', 'Family', 'Action,Drama,Fantasy',
#        'Drama,Sci-Fi,Thriller', 'Drama,Music,Thriller', 'Comedy,Sport',
#        'Comedy,Mystery,Romance', 'Comedy,Crime,Fantasy', 'War',
#        'Action,Sci-Fi,Thriller', 'Comedy,Family,Sport',
#        'Biography,Comedy', 'Animation,Comedy,Musical',
#        'Crime,Horror,Thriller', 'Action,Fantasy', 'Family,Sci-Fi,Western',
#        'Musical', 'Drama,Romance,Sport', 'Action,Animation',
#        'Biography,History', 'Drama,Romance,War', 'Drama,Sci-Fi',
#        'Adventure,Animation', 'Mystery', 'Sci-Fi',
#        'Drama,Musical,Romance', 'Action,Comedy,Thriller',
#        'Comedy,Romance,Sport', 'Action,Adventure', 'Comedy,Drama,History',
#        'Drama,Family,Fantasy', 'Action,Comedy,Drama', 'Family,Horror',
#        'Romance,Thriller', 'Animation,Biography,Drama',
#        'Crime,Horror,Sci-Fi', 'Drama,Fantasy,Horror',
#        'Action,Fantasy,Horror', 'Fantasy,Mystery',
#        'Biography,Drama,Sport', 'Comedy,Horror,Romance', 'Drama,Musical',
#        'Crime,Mystery,Romance', 'Drama,Romance,Sci-Fi',
#        'Fantasy,Horror,Mystery', 'Adventure,Comedy', 'Comedy,History',
#        'Action,Horror,Thriller', 'Action,Drama,War', 'Romance',
#        'Action,Mystery,Sci-Fi', 'Adventure,Drama',
#        'Action,Animation,Drama', 'Comedy,Fantasy,Horror',
#        'Crime,Drama,Fantasy', 'Animation,Family', 'Drama,Fantasy,Mystery',
#        'Adventure,Drama,Family', 'Action,Comedy,Short',
#        'Animation,Family,Fantasy', 'Comedy,Drama,Musical',
#        'Comedy,Fantasy,Sci-Fi', 'Mystery,Romance,Sci-Fi',
#        'Crime,Drama,History', 'Fantasy,Romance', 'Drama,Fantasy,Music',
#        'Fantasy,Sci-Fi', 'Adventure,Comedy,Sport',
#        'Crime,Romance,Thriller', 'Action,Western', 'Sci-Fi,Thriller',
#        'Animation,Comedy,Drama', 'Adventure,Fantasy,Horror',
#        'Animation,Comedy,Family', 'Family,Fantasy',
#        'Action,Musical,Romance', 'Comedy,Drama,War', 'Drama,War,Western',
#        'Horror,Mystery,Romance', 'Biography,Drama,Musical',
#        'Crime,Romance', 'Action,Adventure,Family',
#        'Comedy,Mystery,Sci-Fi', 'Animation,Drama,Fantasy',
#        'Horror,Mystery,Sci-Fi', 'Comedy,Western', 'Comedy,Musical,Sci-Fi',
#        'Drama,History,Music', 'Adventure,Drama,Fantasy',
#        'Action,Sci-Fi,Sport', 'Animation,Crime,Drama',
#        'Adventure,Fantasy,Western', 'Drama,Fantasy,Thriller',
#        'Action,Horror,Mystery', 'Adventure,Family,Sci-Fi',
#        'Family,Fantasy,Music', 'Action,Biography,Drama',
#        'Drama,Family,History', 'Horror,Sci-Fi', 'Thriller,Western',
#        'Animation', 'Fantasy,Romance,Thriller', 'Animation,Sci-Fi',
#        'Action,Romance', 'Adult,Sci-Fi', 'Sport', 'History',
#        'Action,Adventure,Horror', 'Adult,Comedy,Reality-TV',
#        'Action,Fantasy,Thriller', 'Fantasy,Mystery,Romance',
#        'Action,History', 'Action,Fantasy,Sci-Fi', 'Drama,Music,War',
#        'Drama,Family,Sport', 'Adventure,Biography,Comedy', 'Horror,War',
#        'Family,Thriller', 'Adventure,Comedy,Mystery',
#        'Action,Drama,Family', 'Horror,Romance',
#        'Adventure,Animation,Sci-Fi', 'Drama,Fantasy,Musical',
#        'Fantasy,Horror,Thriller', 'Biography,History,Romance',
#        'Family,Romance', 'Drama,Horror,Romance', 'Western',
#        'Comedy,Drama,Horror', 'Biography,Comedy,Crime',
#        'Adventure,Romance', 'Comedy,Crime,Family', 'Comedy,Family,Sci-Fi',
#        'Comedy,Mystery,Thriller', 'Action,Comedy,Family',
#        'Crime,Drama,Sport', 'Drama,Family,Romance', 'Music',
#        'Horror,Western', 'Action,Comedy,Horror',
#        'Action,Animation,Horror', 'Action,Animation,Crime',
#        'Action,Drama,Music', 'Comedy,Family,Music', 'Adventure,Western',
#        'Action,Comedy,Mystery', 'Drama,Fantasy,War',
#        'Action,Adventure,Biography', 'Adventure,Fantasy',
#        'Drama,Horror,Musical', 'Comedy,Romance,Thriller',
#        'Crime,Horror,Romance', 'Family,Mystery', 'Drama,Fantasy,Sci-Fi',
#        'Horror,Musical', 'Comedy,Crime,Musical', 'Action,Drama,Mystery',
#        'Mystery,Sci-Fi,Thriller', 'Mystery,Western',
#        'Drama,Horror,Sci-Fi', 'Biography,Drama,Family',
#        'Action,Crime,Horror', 'Biography,War', 'Action,Drama,Horror',
#        'Adventure,Drama,War', 'Adventure,Family,Mystery',
#        'Action,Animation,Comedy', 'Drama,Musical,Mystery', 'Adult,Drama',
#        'Adventure,Animation,Musical', 'Romance,War', 'Crime,Drama,War',
#        'Adventure,Animation,Biography', 'Animation,Drama',
#        'Adventure,Animation,Fantasy', 'Adventure,Mystery,Thriller',
#        'Animation,Comedy', 'Biography,Crime,Horror',
#        'Adventure,Animation,Romance', 'Comedy,War',
#        'Horror,Thriller,Western', 'Adventure,Drama,Mystery',
#        'Adventure,Horror,Thriller', 'History,Musical,Romance',
#        'Action,Horror', 'Musical,Romance,Thriller',
#        'Comedy,Musical,Mystery', 'Action,Sport',
#        'Adventure,Drama,Thriller', 'Adventure,Horror,Mystery',
#        'Fantasy,History', 'Fantasy,Horror,Romance',
#        'Biography,Drama,Mystery', 'Animation,Fantasy,History',
#        'Action,Biography,Crime', 'Adult,Romance,Thriller',
#        'Comedy,Fantasy,Mystery', 'Adventure,Crime,Thriller',
#        'Drama,Fantasy,History', 'Drama,Music,Musical',
#        'Biography,Drama,Thriller', 'Adventure,Horror,Sci-Fi',
#        'Action,Romance,Sci-Fi', 'Action,Crime,Romance',
#        'Comedy,Horror,Music', 'Drama,History,Musical',
#        'Comedy,History,Romance', 'Action,Adventure,War',
#        'Drama,History,Sport', 'Action,Family,Sci-Fi',
#        'Comedy,Family,Musical', 'Comedy,Crime,Horror',
#        'Musical,Sci-Fi,Thriller', 'Action,Drama,Western',
#        'Action,Comedy,Musical', 'Adventure,Thriller,Western',
#        'Action,Comedy,Western', 'Adventure,Fantasy,Sci-Fi',
#        'Fantasy,Thriller', 'Adventure,Romance,Thriller', 'Crime,Western',
#        'Comedy,Crime,Music', 'Action,Biography,History',
#        'Action,Adventure,Mystery', 'Action,Horror,Romance',
#        'Action,Biography', 'Action,Fantasy,Romance',
#        'Animation,Drama,Mystery', 'Drama,Family,Musical',
#        'Adventure,Thriller', 'Adventure,Drama,Horror', 'Adult,Horror',
#        'Adventure,Comedy,Thriller', 'Adventure,Comedy,Horror',
#        'Comedy,Fantasy,Musical', 'Animation,Comedy,Music',
#        'Adult,Animation,Horror', 'Adventure,Sci-Fi',
#        'Family,Music,Musical', 'Music,Sci-Fi', 'Animation,Horror,Sci-Fi',
#        'Drama,Family,Mystery', 'Animation,Comedy,Horror',
#        'Crime,Drama,Family', 'Adventure,Comedy,Music',
#        'Fantasy,Sci-Fi,Thriller', 'Adventure,Crime,Drama',
#        'Adventure,Animation,Music', 'Adventure,Comedy,Sci-Fi',
#        'Animation,Drama,Sci-Fi', 'Crime,Mystery,Sci-Fi',
#        'Animation,Drama,Romance', 'Animation,Fantasy,Musical',
#        'Animation,Fantasy,Sci-Fi', 'Adventure,Drama,Sci-Fi',
#        'Action,Animation,Sport', 'Action,Sci-Fi,Western',
#        'Family,Fantasy,Musical', 'Action,Animation,Family',
#        'Crime,Musical', 'Drama,Sport,Thriller', 'Crime,Fantasy',
#        'Comedy,Horror,Musical', 'Action,Animation,Sci-Fi',
#        'Action,Animation,Romance', 'Fantasy,Musical,Romance',
#        'Fantasy,Horror,Sci-Fi', 'Crime,Horror,Western',
#        'Animation,Fantasy', 'Mystery,Romance,Thriller',
#        'Comedy,Crime,Sport', 'Animation,Drama,Thriller',
#        'Animation,Biography', 'Adventure,Drama,Music',
#        'Family,Fantasy,Sci-Fi', 'Thriller,War', 'Comedy,Fantasy,Thriller',
#        'Action,History,War', 'Romance,Sci-Fi,Thriller', 'Fantasy,Western',
#        'Action,Romance,War', 'Comedy,Family,Thriller', 'Family,Musical',
#        'Mystery,Romance', 'Action,Horror,War', 'Action,Mystery',
#        'Action,Thriller,War', 'Biography,Drama,War',
#        'Crime,Drama,Western', 'Crime,Horror,Musical',
#        'Biography,Fantasy,History', 'Animation,Fantasy,Horror',
#        'Horror,Music,Sci-Fi', 'Biography,Comedy,Romance',
#        'Drama,Mystery,Short', 'Drama,History,Horror', 'Adventure,Mystery',
#        'Adventure,Family,History', 'Adventure,Comedy,History',
#        'Action,Thriller,Western', 'Animation,Comedy,Romance',
#        'Action,Fantasy,Musical', 'Drama,Music,Mystery',
#        'Fantasy,Horror,War', 'Adventure,Horror', 'Family,Fantasy,Mystery',
#        'History,War', 'Animation,Thriller', 'Action,Adventure,Music',
#        'Adventure,Crime,Family', 'Biography,Comedy,Horror',
#        'Mystery,Sci-Fi', 'Biography,Comedy,Sci-Fi', 'Family,Western',
#        'Adventure,Comedy,Western', 'Drama,Music,Sci-Fi',
#        'Music,Musical,Romance', 'Adventure,Fantasy,Thriller',
#        'Comedy,History,War', 'Action,Adventure,History',
#        'Adventure,Biography,War', 'Comedy,Fantasy,Music',
#        'Action,Comedy,War', 'Biography,Drama,Fantasy',
#        'Crime,Fantasy,Horror', 'Adventure,Drama,Sport', 'Adult,Comedy',
#        'Biography,Crime,Thriller', 'Music,Romance',
#        'Crime,Musical,Mystery', 'Adult,Fantasy', 'Family,History',
#        'Romance,Sport', 'Family,Sport', 'News',
#        'Adventure,Family,Romance', 'Horror,Romance,Thriller',
#        'Adventure,Family,Western', 'Drama,History,Mystery',
#        'Adventure,Crime,Horror', 'Horror,Sport,Thriller',
#        'Comedy,Crime,Western', 'Comedy,Music,Musical',
#        'Animation,Family,Western', 'Action,Horror,Western',
#        'Biography,Music', 'Musical,War', 'Action,Comedy,Sport',
#        'Action,Comedy,Music', 'Adventure,Animation,Mystery',
#        'Comedy,Drama,Western', 'Animation,Horror,Mystery',
#        'Comedy,Horror,Western', 'Comedy,Family,Western',
#        'Family,Fantasy,History', 'Comedy,Crime,Sci-Fi',
#        'Action,Crime,History', 'Animation,Horror',
#        'Action,Adventure,Western', 'Animation,Music',
#        'Adventure,Crime,Mystery', 'Fantasy,Mystery,Sci-Fi',
#        'Drama,Mystery,War', 'Biography,Drama,Horror', 'Animation,History',
#        'Animation,Fantasy,Romance', 'Crime,Drama,Sci-Fi',
#        'Action,Mystery,Romance', 'Biography,History,War', 'Action,Family',
#        'Action,Crime,Musical', 'Crime,Thriller,War',
#        'Adventure,Fantasy,History', 'Crime,Fantasy,Thriller',
#        'Animation,Family,History', 'Horror,Musical,Sci-Fi',
#        'Animation,Crime,Music', 'Animation,Crime,Mystery',
#        'Adventure,Music', 'Drama,Family,Music', 'Drama,Thriller,Western',
#        'Comedy,Crime,History', 'Adventure,Animation,History',
#        'Adult,Romance', 'Drama,History,Sci-Fi', 'Fantasy,Sport',
#        'Animation,Musical,Sport', 'Family,History,Musical',
#        'Musical,Thriller', 'Adventure,History,Mystery', 'Fantasy,Musical',
#        'Biography,Family', 'Reality-TV', 'Action,Fantasy,History',
#        'History,Horror,Thriller', 'History,Romance,Thriller',
#        'Biography,Fantasy', 'Adventure,Crime', 'Talk-Show',
#        'Biography,History,Thriller', 'Animation,Sport', 'Biography,Crime',
#        'Adventure,Drama,Musical', 'Crime,Family',
#        'Adventure,Mystery,Romance', 'Adventure,Fantasy,Mystery',
#        'Action,Fantasy,Western', 'Action,Animation,Fantasy',
#        'Action,Music', 'Crime,Music,Romance', 'Comedy,Fantasy,History',
#        'Action,Family,Fantasy', 'Action,Sport,Thriller',
#        'Biography,Sport', 'Comedy,Sci-Fi,Thriller',
#        'Animation,Musical,Romance', 'History,Sci-Fi',
#        'Animation,Drama,War', 'Animation,Drama,Musical',
#        'Animation,Crime', 'Drama,Family,Sci-Fi', 'Comedy,Horror,Sport',
#        'Animation,Mystery,Sci-Fi', 'Family,Fantasy,Horror',
#        'Fantasy,Horror,Musical', 'Animation,Sci-Fi,War',
#        'Animation,Fantasy,Music', 'Fantasy,Music,Musical',
#        'Short,Thriller', 'Adult,Drama,Romance', 'Adult,Animation,Drama',
#        'Animation,Biography,Comedy', 'Romance,Thriller,War',
#        'Adventure,Animation,Crime', 'Animation,Musical',
#        'Adventure,Horror,Romance', 'Horror,Music', 'Action,Family,Sport',
#        'Fantasy,Music,Mystery', 'Romance,Western', 'Adult,Comedy,Drama',
#        'Adventure,Comedy,Musical', 'Comedy,Reality-TV,Romance',
#        'Animation,Sci-Fi,Thriller', 'Biography,Music,Mystery',
#        'Action,Biography,Comedy', 'Fantasy,History,Romance',
#        'Sci-Fi,Western', 'Drama,Family,Thriller', 'Animation,Drama,Music',
#        'Short', 'Adventure,History', 'Adventure,Horror,Musical',
#        'Drama,Horror,Music', 'Music,Romance,Sci-Fi',
#        'Fantasy,History,Music', 'Crime,Family,Mystery',
#        'History,Thriller', 'Sci-Fi,War', 'Adult,Music',
#        'Action,Animation,Thriller', 'Adult,Comedy,Music',
#        'Comedy,Mystery,Sport', 'Biography,Musical',
#        'Fantasy,Music,Romance', 'Family,Romance,Sci-Fi',
#        'Drama,Musical,Thriller', 'Animation,Horror,Romance',
#        'Adventure,Animation,Horror', 'Animation,History,War',
#        'Action,Family,Romance', 'Drama,History,Western',
#        'Action,Family,Thriller', 'Action,History,Thriller',
#        'Action,Crime,Sport', 'History,Horror', 'Fantasy,Music',
#        'Action,Music,Musical', 'Animation,Family,Romance', 'Game-Show',
#        'Family,Music,Romance', 'Musical,Sci-Fi', 'Music,Musical',
#        'Drama,News', 'Horror,Thriller,War', 'Comedy,Talk-Show',
#        'Comedy,Drama,Short', 'Adventure,Biography', 'News,Talk-Show',
#        'Adult,Comedy,Crime', 'History,Romance', 'Fantasy,Romance,Sci-Fi',
#        'Biography,Comedy,Music', 'Drama,Musical,War',
#        'Adult,Horror,Thriller', 'Adventure,Reality-TV',
#        'Drama,Horror,Sport', 'Horror,Musical,Thriller', 'Family,Music',
#        'Animation,Crime,Sci-Fi', 'Crime,Romance,Sci-Fi',
#        'Animation,Mystery,Thriller', 'Adventure,War',
#        'Crime,Thriller,Western', 'Crime,Family,Musical',
#        'Action,History,Musical', 'Family,Musical,Romance',
#        'Comedy,History,Horror', 'Biography,Crime,History',
#        'Animation,Family,Music', 'History,Music', 'Action,Sci-Fi,War',
#        'History,Musical,War', 'Crime,Fantasy,Romance',
#        'Comedy,Reality-TV', 'Adult,Drama,Reality-TV',
#        'Action,Adventure,Sport', 'Biography,Music,Musical',
#        'Crime,History', 'Crime,History,Thriller',
#        'Adventure,Drama,Western', 'Horror,Music,Musical',
#        'Adult,Thriller', 'Adult,Drama,Fantasy',
#        'Adventure,Fantasy,Romance', 'Comedy,Short',
#        'Action,Fantasy,Mystery', 'Crime,War',
#        'Fantasy,Reality-TV,Romance', 'Biography,Thriller',
#        'Adventure,Mystery,Sci-Fi', 'Animation,Mystery',
#        'Reality-TV,Western', 'Animation,Fantasy,Mystery',
#        'Biography,Comedy,History', 'Animation,Family,Sci-Fi',
#        'Sci-Fi,Short,Thriller', 'Musical,Sport', 'Family,Musical,Mystery',
#        'Comedy,Crime,War', 'Family,Romance,Sport', 'Drama,Horror,War',
#        'Drama,Musical,Short', 'Biography,Comedy,Mystery',
#        'Comedy,Music,Thriller', 'Biography,Romance', 'Sport,Thriller',
#        'Music,Sport', 'Adventure,Family,Music', 'Family,Music,Sport',
#        'Animation,Drama,Sport', 'Music,News', 'Adult,Fantasy,Romance',
#        'Comedy,Musical,Thriller', 'Animation,Biography,History',
#        'Drama,Musical,Sci-Fi', 'Action,Crime,Family',
#        'Adult,Biography,Drama', 'Adult,Comedy,Horror',
#        'Animation,Comedy,War', 'Mystery,Thriller,Western',
#        'Adventure,Fantasy,Musical', 'Adventure,Biography,Crime',
#        'Action,Adult,Drama', 'Comedy,Game-Show,Horror',
#        'Adult,Drama,Mystery', 'Crime,Sci-Fi', 'Animation,Comedy,Mystery',
#        'Game-Show,Sport', 'Animation,Biography,Family', 'Family,Sci-Fi',
#        'Drama,Short', 'Adventure,Horror,Western', 'Drama,Family,Horror',
#        'Biography,Mystery,Sci-Fi', 'Biography,Romance,War',
#        'Comedy,Music,Mystery', 'Adult,Adventure,Comedy',
#        'Horror,Mystery,Western', 'Action,History,Horror',
#        'Adventure,Comedy,Game-Show', 'History,Mystery,Thriller',
#        'Adventure,Comedy,War', 'History,Mystery,Sci-Fi',
#        'Action,Fantasy,War', 'Fantasy,Mystery,Thriller',
#        'Animation,Biography,Music', 'Adventure,Biography,Thriller',
#        'Crime,History,Mystery', 'Adventure,Crime,Romance',
#        'Animation,History,Musical', 'Adventure,Biography,History',
#        'Comedy,Music,Sci-Fi', 'Biography,Comedy,Family',
#        'Animation,Horror,Thriller', 'Drama,Fantasy,Western',
#        'Biography,History,Music', 'Adult,Drama,Horror',
#        'Comedy,Thriller,Western', 'Adventure,Fantasy,Music',
#        'Action,Crime,Music', 'Family,Mystery,Thriller',
#        'Animation,Music,Musical', 'Animation,Family,Sport',
#        'Animation,Biography,Fantasy', 'Adventure,Family,Horror',
#        'Adult,Drama,Thriller', 'Animation,Music,Romance',
#        'Adult,Crime,Drama', 'Action,Family,Mystery',
#        'Action,Animation,Game-Show', 'History,Thriller,War',
#        'Horror,Reality-TV,Talk-Show', 'Action,Comedy,History',
#        'Fantasy,Horror,Western', 'Action,Romance,Sport',
#        'Family,Musical,Sport', 'Comedy,Game-Show', 'Comedy,History,Music',
#        'Horror,Music,Mystery', 'Adventure,Family,Musical',
#        'Adventure,Sport', 'Comedy,History,Mystery',
#        'Action,Musical,Thriller', 'Fantasy,Musical,Sci-Fi',
#        'Adventure,History,Music', 'Drama,Sci-Fi,Sport',
#        'Adventure,History,War', 'Adventure,Romance,Sport',
#        'Horror,Music,Thriller', 'Action,Music,Sci-Fi',
#        'Adventure,Reality-TV,Sport', 'Biography,Comedy,War',
#        'Adventure,History,Thriller', 'Comedy,News,Talk-Show',
#        'News,Reality-TV', 'Fantasy,Horror,Music',
#        'Adventure,Biography,Mystery', 'Biography,Music,Romance',
#        'Comedy,Musical,Sport', 'History,Mystery', 'Adult,Drama,Sci-Fi',
#        'Fantasy,Music,Sci-Fi', 'Adventure,Crime,Sci-Fi',
#        'Drama,Sci-Fi,Western', 'Comedy,Drama,News',
#        'Animation,Drama,Horror', 'Comedy,Musical,Western',
#        'Biography,Drama,News', 'Family,Horror,Thriller',
#        'Comedy,Family,Horror', 'Comedy,News', 'Comedy,History,Thriller',
#        'Family,Fantasy,Western', 'Biography,Family,Mystery',
#        'Action,Horror,Sport', 'Music,Mystery,Romance',
#        'Crime,Music,Mystery', 'Drama,Horror,Western',
#        'Drama,Mystery,Western', 'Horror,Romance,Sci-Fi',
#        'History,Western', 'Animation,Romance,Sci-Fi',
#        'Crime,Family,Thriller', 'Adult,Mystery', 'Animation,Music,Sci-Fi',
#        'Adventure,Crime,Western', 'Action,Animation,History',
#        'Drama,Sci-Fi,War', 'Drama,Mystery,Sport', 'Drama,Musical,Western',
#        'Biography,History,Mystery', 'Adventure,History,Western',
#        'Action,Adventure,Musical', 'Biography,Comedy,Fantasy',
#        'Action,Family,Western', 'Animation,Biography,Crime',
#        'Adventure,History,Romance', 'Action,Musical',
#        'Biography,History,Musical', 'Adventure,Music,Sci-Fi',
#        'Crime,Music,Thriller', 'Biography,Family,Sport',
#        'Family,History,War', 'Animation,Comedy,History',
#        'Comedy,Family,History', 'Biography,Horror',
#        'Action,Adventure,Game-Show', 'Adventure,Romance,Sci-Fi',
#        'Action,Musical,Sci-Fi', 'Family,Horror,Romance',
#        'Fantasy,History,Mystery', 'Animation,War', 'Comedy,Music,War',
#        'Crime,Musical,Thriller', 'Animation,Horror,Music',
#        'Biography,Family,History', 'Action,Drama,News',
#        'Adventure,Music,Mystery', 'Comedy,Sport,Western', 'Sci-Fi,Short',
#        'Comedy,Sci-Fi,Western', 'Action,Biography,Thriller',
#        'Biography,Crime,Romance', 'Comedy,Sci-Fi,Sport',
#        'Drama,News,Sci-Fi', 'Adult,Adventure', 'Action,Biography,Fantasy',
#        'Adventure,Family,Sport', 'Family,Fantasy,Romance',
#        'Adventure,Musical', 'Adventure,Music,Romance',
#        'History,Music,Sci-Fi', 'Action,Animation,Mystery',
#        'Animation,History,Music', 'Horror,Reality-TV,Sci-Fi',
#        'Adventure,Biography,Family', 'Action,Animation,Music',
#        'Action,Romance,Western', 'Action,Mystery,Western',
#        'Music,Musical,Thriller', 'Music,Musical,Mystery',
#        'Animation,Romance', 'Biography,History,Talk-Show',
#        'Adventure,Music,Thriller', 'Drama,Mystery,News', 'War,Western',
#        'Action,Animation,Biography', 'Animation,Fantasy,Thriller',
#        'Comedy,Horror,War', 'Action,Horror,Music',
#        'Family,Musical,Sci-Fi', 'Family,Horror,Mystery',
#        'Comedy,Reality-TV,Short', 'Adult,Crime', 'Drama,Reality-TV',
#        'Biography,Comedy,Musical', 'Mystery,Thriller,War',
#        'Action,Family,Horror', 'Family,History,Romance',
#        'Music,Mystery,Thriller', 'History,News,War', 'Adventure,News',
#        'History,Horror,Mystery', 'Sport,Talk-Show', 'History,Romance,War',
#        'History,Sci-Fi,Thriller', 'Adventure,Musical,Sci-Fi',
#        'Reality-TV,Sport', 'Adult,Adventure,Romance',
#        'Musical,Reality-TV', 'Music,Thriller', 'Fantasy,History,Sci-Fi',
#        'Music,War', 'Biography,Drama,Western', 'Animation,Western',
#        'Action,History,Romance', 'Animation,Music,Mystery',
#        'Family,Mystery,Sport', 'Adventure,Musical,Romance',
#        'Biography,Family,News', 'Action,Crime,Western', 'History,Musical',
#        'Animation,Crime,Thriller', 'Biography,Thriller,Western',
#        'Adult,Crime,Thriller', 'Crime,History,Horror',
#        'Thriller,War,Western', 'Musical,Romance,Sport',
#        'Horror,Sci-Fi,War', 'Fantasy,War', 'Comedy,History,Musical',
#        'History,Sport,Thriller', 'Fantasy,Musical,Mystery',
#        'Comedy,Sport,Thriller', 'Action,Adult,Comedy',
#        'Adventure,Fantasy,War', 'Adventure,Crime,History', 'Mystery,War',
#        'Action,Adult,Crime', 'Comedy,History,Sport', 'Crime,Fantasy,War',
#        'Family,Horror,War', 'Fantasy,History,Musical',
#        'Comedy,Fantasy,Sport', 'History,Mystery,Romance', 'History,Sport',
#        'Biography,Thriller,War', 'Adventure,Crime,Music',
#        'Crime,Mystery,Western', 'Sport,War', 'Action,Reality-TV',
#        'Biography,History,Horror', 'Family,War', 'Musical,Mystery,Sci-Fi',
#        'Crime,Fantasy,History', 'Biography,Crime,Western', 'Crime,Music',
#        'Adventure,Biography,Western', 'Adventure,History,Sci-Fi',
#        'Crime,Romance,Western', 'Family,History,Mystery',
#        'Musical,Romance,Western', 'Adventure,Romance,Western',
#        'Family,Sci-Fi,Thriller', 'Drama,Reality-TV,Romance',
#        'Fantasy,History,War', 'Biography,Crime,Fantasy',
#        'History,Reality-TV,War', 'Mystery,Reality-TV,Thriller',
#        'Music,Musical,Reality-TV', 'Action,Crime,Short',
#        'Action,History,Western', 'Crime,Fantasy,Sci-Fi'], dtype=object)

# %%
# just us movies
akas = akas.loc[akas['region'] == 'US']

# %%
keepers = basics['tconst'].isin(akas['titleId'])

# %%
basics= basics[keepers]

# %%
basics
# Out:
#             tconst titleType  \
# 34790    tt0035423     movie
# 61089    tt0062336     movie
# 67634    tt0069049     movie
# 86765    tt0088751     movie
# 92730    tt0094859     movie
# ...            ...       ...
# 9151011  tt9914942     movie
# 9151407  tt9915872     movie
# 9151547  tt9916170     movie
# 9151556  tt9916190     movie
# 9151640  tt9916362     movie
#
#                                               primaryTitle  \
# 34790                                       Kate & Leopold
# 61089    The Tango of the Widower and Its Distorting Mi...
# 67634                           The Other Side of the Wind
# 86765                                    The Naked Monster
# 92730                                           Chief Zabu
# ...                                                    ...
# 9151011                             Life Without Sara Amat
# 9151407                               The Last White Witch
# 9151547                                      The Rehearsal
# 9151556                                          Safeguard
# 9151640                                              Coven
#
#                                      originalTitle isAdult  startYear endYear  \
# 34790                               Kate & Leopold       0       2001     NaN
# 61089    El Tango del Viudo y Su Espejo Deformante       0       2020     NaN
# 67634                   The Other Side of the Wind       0       2018     NaN
# 86765                            The Naked Monster       0       2005     NaN
# 92730                                   Chief Zabu       0       2016     NaN
# ...                                            ...     ...        ...     ...
# 9151011                 La vida sense la Sara Amat       0       2019     NaN
# 9151407                  My Girlfriend is a Wizard       0       2019     NaN
# 9151547                                   O Ensaio       0       2019     NaN
# 9151556                                  Safeguard       0       2020     NaN
# 9151640                                   Akelarre       0       2020     NaN
#
#         runtimeMinutes                     genres
# 34790              118     Comedy,Fantasy,Romance
# 61089               70                      Drama
# 67634              122                      Drama
# 86765              100       Comedy,Horror,Sci-Fi
# 92730               74                     Comedy
# ...                ...                        ...
# 9151011             74                      Drama
# 9151407             97       Comedy,Drama,Fantasy
# 9151547             51                      Drama
# 9151556             95  Action,Adventure,Thriller
# 9151640             92              Drama,History
#
# [82108 rows x 9 columns]
